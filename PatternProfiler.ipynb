# %%
### the goal of this notebook is just to get a better handle on how slow it will be to run
### many games in the current set up, and decide whether there is a better way to be doing it


""" 
todo

1. make it so that we explore to a bunch of random stuff and then start playing, 
    BUT we don't want to save any games that are WON or LOST from random play...
2. keep working on efficiency gains that will make the whole loop work well
3. think of how to work tournaments in, with several different networks
4. way to save lots of different iterations and generations of games down, to learn from
    
"""

# %%
import random
import matplotlib.pyplot as plt
import datetime
import os
from pathlib import Path

import numpy as np
import copy
from importlib import reload
import torch
import int_to_board
import pickle

reload(int_to_board)

import game
reload(game)

import plotting
reload(plotting)

import mcts.mcts
reload(mcts.mcts)

import mcts.networks
reload(mcts.networks)

import mcts.agent
reload(mcts.agent)

import augmentor
reload(augmentor)

from game import Patterns
from plotting import PatternPlotter

from mcts.mcts import Tree, Node
from mcts.networks import PatternsNet
from mcts.agent import Agent

from augmentor import StateAugmentor

rseed = 12387623
random.seed(rseed)
torch.manual_seed(rseed)
np.random.seed(rseed)

my_device = torch.device("cuda:0") if torch.cuda.is_available() else torch.device("cpu")

# %%
# Load up previous best networks to help play the games (lets see how it does!).
# in time, have best of a generation playing against each other!
network_path = os.path.join(Path.cwd(), 'saved_networks', 'v4', '2025_07_11_15_25.pt')
my_network = PatternsNet(in_channels=47, out_channels=128)
my_network.load_state_dict(torch.load(network_path, weights_only=True))
# Out:
# <All keys matched successfully>

# %%
### Agent parameters:
NUM_TREES = 500
TARGET_GAMES = 500
NUM_IT = 1 # 1 validation, 15*30k games:
SCHEDULE = [
    (0, 0), # explore randomly for the first moves:
    (1, 250), # explore with search tree after depth 1:
]

SAVE_DEPTH = 5

TOPN = 10
RANDN = 5
SELECTION_TEMP = None

# %%
my_agent = Agent(
        agent_id='1', # not relevant for a single machine:
        network = my_network,
        device = my_device,
        num_trees = NUM_TREES, # number of in series trees to use:
        target_games = TARGET_GAMES, # total number of games in the data set
        selection_temperature = SELECTION_TEMP,
        topn=TOPN, # only explore the top 5 best moves
        randn=RANDN, # explore an additional 5 random moves
        save_depth=SAVE_DEPTH, # for this, only save the final state and move
        explore_steps_schedule=SCHEDULE,  
        debug=False,
    )
# Out:
# Generating initial games:
# Evaluating tensor states...
# Provisioning inference to root nodes...

# %%
# run the games until target amount reached:
# %prun my_agent.run_games()
# Out:
# 1 games have been completed!
# 2 games have been completed!
# 3 games have been completed!
# 4 games have been completed!
# 5 games have been completed!
# 6 games have been completed!
# 7 games have been completed!
# 8 games have been completed!
# 9 games have been completed!
# 10 games have been completed!
# 11 games have been completed!
# 12 games have been completed!
# 13 games have been completed!
# 14 games have been completed!
# 15 games have been completed!
# 16 games have been completed!
# 17 games have been completed!
# 18 games have been completed!
# 19 games have been completed!
# 20 games have been completed!
# 21 games have been completed!
# 22 games have been completed!
# 24 games have been completed!
# 25 games have been completed!
# 26 games have been completed!
# 27 games have been completed!
# 28 games have been completed!
# 29 games have been completed!
# 30 games have been completed!
# 31 games have been completed!
# 32 games have been completed!
# 33 games have been completed!
# 34 games have been completed!
# 35 games have been completed!
# 36 games have been completed!
# 37 games have been completed!
# 39 games have been completed!
# 40 games have been completed!
# 41 games have been completed!
# 42 games have been completed!
# 43 games have been completed!
# 44 games have been completed!
#   1465000   19.311    0.000   38.169    0.000 mcts.py:905(back_propagate)
#   7634256   15.902    0.000   18.246    0.000 mcts.py:888(update_parent_child_scores)
#   7598680   14.877    0.000   19.681    0.000 game.py:292(_easy_win_placing)
#   1465000   13.061    0.000  172.178    0.000 mcts.py:808(get_leaf_node)
#   6194815   12.409    0.000   12.409    0.000 {method 'argmax' of 'numpy.ndarray' objects}
#    258559   11.882    0.000   11.882    0.000 game.py:157(<dictcomp>)
#   1137166   11.041    0.000   11.041    0.000 {method 'numpy' of 'torch._C.TensorBase' objects}
#   6194815   10.689    0.000   32.380    0.000 fromnumeric.py:1140(argmax)
#    258559   10.450    0.000   10.450    0.000 game.py:151(<dictcomp>)
#     84970   10.277    0.000   10.277    0.000 {built-in method torch.conv2d}
#   1131306    9.702    0.000    9.702    0.000 mcts.py:442(_tensor_update_score)
#   7608030    9.092    0.000   32.445    0.000 game.py:433(is_action_terminal)
#    258559    8.305    0.000    8.305    0.000 game.py:154(<dictcomp>)
#      2930    7.989    0.003    7.989    0.003 {built-in method torch.stack}
#    258559    7.670    0.000   43.486    0.000 game.py:118(clone)
#   6307093    6.752    0.000   22.553    0.000 fromnumeric.py:53(_wrapfunc)
#    219241    6.153    0.000   44.157    0.000 mcts.py:161(assign_actions_and_policy)
#    219241    6.125    0.000  102.791    0.000 mcts.py:261(populate_attributes_and_assign_children)
#    235089    5.284    0.000    5.284    0.000 fromnumeric.py:72(<dictcomp>)
#      8790    5.134    0.001    5.134    0.001 {method 'to' of 'torch._C.TensorBase' objects}
#      2930    5.068    0.002  438.218    0.150 agent.py:250(explore)
#     84970    4.925    0.000    4.925    0.000 {built-in method torch.batch_norm}
#   1131306    4.836    0.000    4.836    0.000 mcts.py:401(_tensor_update_bowl_tokens)
#   1131306    4.627    0.000    4.627    0.000 mcts.py:373(_tensor_update_board)
#   1131306    4.504    0.000    5.034    0.000 mcts.py:364(_tensor_update_no_more_placing)
#   1131306    4.431    0.000    4.431    0.000 mcts.py:475(_tensor_update_bowl_token_values)
#    234922    4.108    0.000    4.108    0.000 game.py:258(set_possible_placing_coordinates)
#   1131306    3.195    0.000    3.195    0.000 mcts.py:428(_tensor_update_color_order)
#    219241    2.941    0.000   12.655    0.000 mcts.py:231(numpy_softmax)
#  23247589    2.798    0.000    2.798    0.000 {built-in method builtins.len}
#   6307488    2.757    0.000    2.757    0.000 {built-in method builtins.getattr}
#    454330    2.628    0.000    2.628    0.000 {method 'reduce' of 'numpy.ufunc' objects}
#   9533632    2.596    0.000    7.124    0.000 game.py:176(is_no_more_placing)
#  13970200    2.475    0.000    2.475    0.000 {method 'append' of 'list' objects}
#   7633258    2.344    0.000    2.344    0.000 mcts.py:214(calculate_exploitation_score)
#   1131306    2.238    0.000  103.746    0.000 mcts.py:525(create_tensor_state)
#    296570    2.236    0.000    2.236    0.000 game.py:597(remove_new_location)
#   1465000    2.142    0.000  156.571    0.000 mcts.py:238(expand)
#    219241    2.074    0.000   17.052    0.000 mcts.py:174(<listcomp>)
#    605608    2.066    0.000    2.450    0.000 game.py:357(_full_flipping_terminal)
#    296570    1.848    0.000    2.929    0.000 game.py:616(update_placing_and_flipping_groups)
#         1    1.788    1.788  524.197  524.197 agent.py:203(run_games)
#    736359    1.770    0.000    1.770    0.000 {built-in method numpy.array}
#     79110    1.719    0.000    1.719    0.000 {built-in method torch.relu}
# 413130/2930    1.435    0.000   26.752    0.009 module.py:1740(_call_impl)
#    258559    1.366    0.000   15.127    0.000 game.py:478(step)
#     35160    1.342    0.000   20.910    0.001 networks.py:171(forward)
#      2930    1.314    0.000   41.423    0.014 agent.py:282(assign_inference)
#    258559    1.308    0.000    1.308    0.000 game.py:155(<dictcomp>)
#    219241    1.301    0.000   47.663    0.000 mcts.py:140(populate_attributes)
#    258559    1.250    0.000    1.250    0.000 game.py:158(<dictcomp>)
#    219241    1.242    0.000    1.553    0.000 numeric.py:136(ones)
#   6194815    1.213    0.000    1.213    0.000 fromnumeric.py:1136(_argmax_dispatcher)
#    258559    1.147    0.000    1.147    0.000 game.py:152(<dictcomp>)
#    296570    1.134    0.000    7.584    0.000 game.py:574(update_locations)
#    112278    0.999    0.000    0.999    0.000 {method 'shuffle' of 'numpy.random.mtrand.RandomState' objects}
#     84970    0.979    0.000    6.783    0.000 batchnorm.py:159(forward)
#    235089    0.885    0.000    7.869    0.000 fromnumeric.py:71(_wrapreduction)
#     84970    0.876    0.000   22.757    0.000 container.py:248(forward)
#    211149    0.814    0.000    0.814    0.000 game.py:256(<listcomp>)
# 413130/2930    0.812    0.000   26.777    0.009 module.py:1732(_wrapped_call_impl)
#    296570    0.794    0.000    0.794    0.000 game.py:625(<listcomp>)
#    782310    0.750    0.000    0.750    0.000 module.py:1918(__getattr__)
#    112278    0.725    0.000    0.725    0.000 mcts.py:189(<listcomp>)
#   1459824    0.723    0.000    1.380    0.000 mcts.py:708(noise)
#    283294    0.723    0.000    0.723    0.000 game.py:287(<listcomp>)
#    413130    0.713    0.000    0.713    0.000 {built-in method torch._C._get_tracing_state}
#    605608    0.683    0.000    3.673    0.000 game.py:416(_full_is_terminal)
#    424089    0.647    0.000    0.878    0.000 random.py:235(_randbelow_with_getrandbits)
#    424089    0.642    0.000    1.609    0.000 random.py:367(choice)
#    112278    0.637    0.000    0.637    0.000 {method 'argsort' of 'numpy.ndarray' objects}
#   2675345    0.629    0.000    0.629    0.000 {method 'items' of 'dict' objects}
#    296570    0.627    0.000    0.736    0.000 game.py:589(update_board)
#    233176    0.619    0.000    0.619    0.000 game.py:463(swap_players)
#   1465000    0.577    0.000    0.577    0.000 mcts.py:202(calculate_reward)
#    283294    0.561    0.000    1.353    0.000 game.py:274(set_flipping_actions)
#    219241    0.542    0.000    8.185    0.000 fromnumeric.py:2692(max)
#      5860    0.532    0.000    0.532    0.000 {built-in method torch._C._nn.linear}
#    284633    0.498    0.000    5.395    0.000 game.py:218(get_actions)
#    198746    0.470    0.000    0.540    0.000 game.py:382(_full_placing_terminal)
#    283294    0.470    0.000    3.543    0.000 game.py:241(set_placing_actions)
#    323951    0.443    0.000    0.554    0.000 game.py:452(reset_properties)
#     84970    0.429    0.000   11.020    0.000 conv.py:553(forward)
#    112278    0.421    0.000    0.421    0.000 mcts.py:194(<listcomp>)
#    235932    0.420    0.000    4.528    0.000 game.py:190(set_is_no_more_placing)
#    296570    0.418    0.000    0.549    0.000 game.py:607(update_color_groups)
#     16445    0.354    0.000    0.523    0.000 mcts.py:733(choose_action_argument)
#     15453    0.332    0.000    0.592    0.000 {method 'dirichlet' of 'numpy.random.mtrand.RandomState' objects}
#    296570    0.287    0.000    0.287    0.000 game.py:629(<listcomp>)
#    258559    0.283    0.000   43.770    0.000 game.py:61(__init__)
#    219241    0.266    0.000    1.468    0.000 {method 'sum' of 'numpy.ndarray' objects}
#     84970    0.266    0.000    5.295    0.000 functional.py:2781(batch_norm)
#    219241    0.250    0.000    0.250    0.000 {built-in method numpy.empty}
#    112278    0.213    0.000    1.075    0.000 fromnumeric.py:1025(argsort)
#     25383    0.213    0.000    0.240    0.000 game.py:205(calculate_score)
#     16445    0.213    0.000    3.952    0.000 mcts.py:776(step)
#      5860    0.203    0.000    0.203    0.000 {built-in method torch._C._nn.adaptive_avg_pool2d}
#     84970    0.180    0.000   10.458    0.000 conv.py:536(_conv_forward)
#    219241    0.174    0.000    1.202    0.000 _methods.py:47(_sum)
#    694126    0.152    0.000    0.152    0.000 {method 'getrandbits' of '_random.Random' objects}
#     17580    0.150    0.000   21.336    0.001 networks.py:128(forward)
#      2930    0.144    0.000   26.695    0.009 networks.py:59(forward)
#     84970    0.127    0.000    0.179    0.000 container.py:240(__iter__)
#     25383    0.125    0.000    1.424    0.000 game.py:544(finish_game)
#    296570    0.110    0.000    0.110    0.000 {method 'add' of 'set' objects}
#     79110    0.105    0.000    1.950    0.000 activation.py:132(forward)
#     79110    0.101    0.000    1.846    0.000 functional.py:1693(relu)
#     84970    0.096    0.000    0.156    0.000 batchnorm.py:450(_check_input_dim)
#    424089    0.079    0.000    0.079    0.000 {method 'bit_length' of 'int' objects}
#      2930    0.073    0.000    0.073    0.000 {built-in method torch.tanh}
#      5860    0.068    0.000    0.087    0.000 utils.py:35(_list_with_default)
#     15453    0.061    0.000    0.657    0.000 mcts.py:728(set_noise)
#    219241    0.061    0.000    0.061    0.000 fromnumeric.py:2687(_max_dispatcher)
#    219241    0.060    0.000    0.060    0.000 multiarray.py:1080(copyto)
#     84970    0.060    0.000    0.060    0.000 {method 'dim' of 'torch._C.TensorBase' objects}
#      2930    0.054    0.000    0.062    0.000 grad_mode.py:269(__enter__)
#      5860    0.046    0.000    0.046    0.000 {method 'flatten' of 'torch._C.TensorBase' objects}
#     84970    0.044    0.000    0.070    0.000 __init__.py:38(__get__)
#    254866    0.043    0.000    0.043    0.000 {method 'pop' of 'list' objects}
#     15453    0.042    0.000    0.255    0.000 fromnumeric.py:2322(any)
#      2930    0.041    0.000    4.558    0.002 agent.py:229(step_trees)
#      2930    0.040    0.000    3.351    0.001 networks.py:108(forward)
#      5860    0.038    0.000    0.581    0.000 linear.py:124(forward)
#     84970    0.034    0.000    0.034    0.000 {built-in method torch._C._has_torch_function_variadic}
#       500    0.033    0.000    0.039    0.000 mcts.py:968(get_replay_game)
#     16945    0.032    0.000    0.032    0.000 mcts.py:690(determine_required_steps)
#    112278    0.030    0.000    0.030    0.000 fromnumeric.py:1021(_argsort_dispatcher)
#     84970    0.028    0.000    0.028    0.000 {built-in method builtins.iter}
#     84970    0.027    0.000    0.027    0.000 {built-in method torch._C._has_torch_function_unary}
#      5860    0.027    0.000    0.331    0.000 functional.py:1370(adaptive_avg_pool2d)
#     15690    0.026    0.000    0.026    0.000 {built-in method numpy.zeros}
#     84970    0.026    0.000    0.026    0.000 {built-in method torch._C._get_cudnn_enabled}
#     84970    0.024    0.000    0.024    0.000 {method 'values' of 'dict' objects}
#      2930    0.021    0.000    0.021    0.000 {method 'view' of 'torch._C.TensorBase' objects}
#      2930    0.020    0.000    0.021    0.000 grad_mode.py:259(__init__)
#       363    0.019    0.000    0.019    0.000 socket.py:621(send)
#      2930    0.017    0.000    0.022    0.000 grad_mode.py:264(__new__)
#       395    0.015    0.000    0.029    0.000 {method 'choice' of 'numpy.random.mtrand.RandomState' objects}
#      2930    0.015    0.000    0.015    0.000 {built-in method torch._C.__exit__}
#      2930    0.015    0.000    0.015    0.000 {method 'float' of 'torch._C.TensorBase' objects}
#      5860    0.013    0.000    0.013    0.000 {method 'size' of 'torch._C.TensorBase' objects}
#      5860    0.013    0.000    0.344    0.000 pooling.py:1454(forward)
#      5860    0.011    0.000    0.011    0.000 utils.py:42(<listcomp>)
#      5860    0.009    0.000    0.055    0.000 flatten.py:52(forward)
#      2930    0.008    0.000    0.008    0.000 {built-in method torch._C.__enter__}
#      2930    0.007    0.000    0.022    0.000 grad_mode.py:273(__exit__)
#       898    0.006    0.000    0.038    0.000 iostream.py:610(write)
#      9688    0.006    0.000    0.006    0.000 {built-in method builtins.isinstance}
#     15453    0.005    0.000    0.005    0.000 fromnumeric.py:2317(_any_dispatcher)
#      2930    0.005    0.000    0.078    0.000 activation.py:391(forward)
#     13193    0.004    0.000    0.004    0.000 multiarray.py:346(where)
#      2930    0.004    0.000    0.004    0.000 {built-in method __new__ of type object at 0x00007FFD49C3A4B0}
#       363    0.003    0.000    0.027    0.000 iostream.py:243(schedule)
#       449    0.003    0.000    0.041    0.000 {built-in method builtins.print}
#       898    0.002    0.000    0.002    0.000 iostream.py:505(_is_master_process)
#       395    0.002    0.000    0.014    0.000 fromnumeric.py:2979(prod)
#       363    0.001    0.000    0.003    0.000 threading.py:1185(is_alive)
#       898    0.001    0.000    0.028    0.000 iostream.py:532(_schedule_flush)
#       363    0.001    0.000    0.001    0.000 iostream.py:127(_event_pipe)
#      2930    0.001    0.000    0.001    0.000 _jit_internal.py:103(is_scripting)
#       500    0.001    0.000    0.002    0.000 mcts.py:674(reset)
#       898    0.001    0.000    0.001    0.000 {built-in method nt.getpid}
#       898    0.001    0.000    0.001    0.000 {method 'write' of '_io.StringIO' objects}
#       363    0.001    0.000    0.001    0.000 {method 'acquire' of '_thread.lock' objects}
#       363    0.001    0.000    0.001    0.000 threading.py:1118(_wait_for_tstate_lock)
#       363    0.000    0.000    0.000    0.000 threading.py:568(is_set)
#       500    0.000    0.000    0.000    0.000 {method 'extend' of 'list' objects}
#       898    0.000    0.000    0.000    0.000 {method '__exit__' of '_thread.RLock' objects}
#       363    0.000    0.000    0.000    0.000 {method 'append' of 'collections.deque' objects}
#       395    0.000    0.000    0.000    0.000 fromnumeric.py:2974(_prod_dispatcher)
#         1    0.000    0.000  524.197  524.197 {built-in method builtins.exec}
#         1    0.000    0.000  524.197  524.197 <string>:1(<module>)
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}

# %%
puct_scores = np.random.rand(20)
num_actions = 20

losing_action_arguments = [4, 6, 7, 10, 15, 18]

losing_mask = np.zeros(num_actions, dtype=bool)
losing_mask[losing_action_arguments] = True

not_losing_mask = ~losing_mask

# determine which arguments are losing:
masked_scores = np.where(not_losing_mask, puct_scores, -np.inf)
best_arg = np.argmax(masked_scores)

print(puct_scores, best_arg)

# %%
jim = np.

# %%
my_agent.trees[0].

# %%
_leaf = copy_leaf

while _leaf is not None:
    tensor_state = _leaf.tensor_state
    aug = StateAugmentor(state=tensor_state)
    new_game = aug.create_game_from_state()
    print(new_game.calculate_score())
    print(sorted(new_game.get_actions()))
    pplotter = PatternPlotter(new_game)
    pplotter.plot()
    _leaf = _leaf.parent

# %%
game = copy.deepcopy(new_game)

# %%
p1_order = game.active_color_order if game.active_player == 1 else game.passive_color_order
p2_order = game.active_color_order if game.active_player == -1 else game.passive_color_order
player_orders = [p1_order, p2_order]

# assign the color groups to each player:
p1_color_groups = game.active_color_groups if game.active_player == 1 else game.passive_color_groups
p2_color_groups = game.active_color_groups if game.active_player == -1 else game.passive_color_groups
player_color_groups = [p1_color_groups, p2_color_groups]

token_points = [8, 4]
y_offsets = [[0.0, -1.2], [-1.2, 0.0]]
face_colors = [(0.8, 0.1, 0.8), (0.8, 0.8, 0.9)]

# %%
from matplotlib import patches

# %%
_leaf.game.passive_color_order

# %%
leaf_game = copy.deepcopy(_leaf.game)
parent_game = copy.deepcopy(_leaf.parent.game)
tensor_game = copy.deepcopy(game)

# %%
leaf_game.passive_color_order, parent_game.active_color_order, tensor_game.passive_color_order

# %%
parent_game.active_bowl_token, _leaf.parent_action_arg, _leaf.parent.possible_actions

# %%
leaf_game.passive_color_groups, parent_game.active_color_groups, tensor_game.passive_color_groups

# %%
p2_order, p2_color_groups

# %%
pcgroup, porder

# %%
fig, axis = plt.subplots()

for porder, pcgroup, tstart, npoints, fcol, yoff in zip(player_orders, player_color_groups,
                                                        pplotter.token_starts, token_points,
                                                        face_colors, y_offsets):
    # populate the ordering tiles for each player, from 1-6:
    untaken = 5

    for _color, _order in enumerate(porder):
        # if color group exists, place star token on board and indicate color order in token row:
        if _order > 0:
            # add color token to token row:
            color_center = (tstart[0] + 1.2 * (_order - 1), tstart[1] + yoff[0])
            axis.add_patch(patches.Circle(color_center,
                                          radius=0.35,
                                          alpha=0.8,
                                          facecolor=pplotter.token_colors[_color],
                                          edgecolor='black',
                                          linewidth=0.5))

            # place star token over the first color taken in the group:
            token_coordsij = pcgroup[_color][0]
            token_coords = (token_coordsij[1], 7 - token_coordsij[0])
            token_string = str(_order)

        else:
            token_coords = (tstart[0] + 1.2 * untaken, tstart[1] + yoff[1])
            token_string = str(untaken + 1)
            untaken -= 1

        star_patch = pplotter.get_star_token(token_coords,
                                         num_points=npoints,
                                         face_color=fcol)
        axis.add_patch(star_patch)
        axis.text(token_coords[0], token_coords[1],
                  token_string,
                  fontsize=12.,
                  horizontalalignment='center',
                  verticalalignment='center', )

# %%
pplotter.plot()

# %%
james = [1, 2, 3]
jim = james[:]
jim[0] = 5
james[1] = 20
jim, james
